# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %% [markdown]
# # Read dataset GNI_Surface

# %% [markdown]
# ### Import dataset

# %%
dfgni = pd.read_csv("GNI_Surface_Data.txt",sep="\t",header=0)
dfgni.head()
# Out:
#    Time Time Code    Country Name Country Code           GNI    Surface
# 0  2010    YR2010     Afghanistan          AFG  1.599880e+10   652860.0
# 1  2010    YR2010         Albania          ALB  1.180780e+10    28750.0
# 2  2010    YR2010         Algeria          DZA  1.608199e+11  2381740.0
# 3  2010    YR2010  American Samoa          ASM           NaN      200.0
# 4  2010    YR2010         Andorra          AND           NaN      470.0

# %% [markdown]
# ### Drop rows with missing values

# %%
dfgni = dfgni.dropna()
dfgni
# Out:
#      Time Time Code            Country Name Country Code           GNI  \
# 0    2010    YR2010             Afghanistan          AFG  1.599880e+10
# 1    2010    YR2010                 Albania          ALB  1.180780e+10
# 2    2010    YR2010                 Algeria          DZA  1.608199e+11
# 5    2010    YR2010                  Angola          AGO  7.443928e+10
# 6    2010    YR2010     Antigua and Barbuda          ATG  1.120980e+09
# 7    2010    YR2010              Arab World          ARB  2.091921e+12
# 8    2010    YR2010               Argentina          ARG  4.091479e+11
# 9    2010    YR2010                 Armenia          ARM  9.718566e+09
# 11   2010    YR2010               Australia          AUS  1.099736e+12
# 12   2010    YR2010                 Austria          AUT  3.951709e+11
# 13   2010    YR2010              Azerbaijan          AZE  4.973489e+10
# 14   2010    YR2010            Bahamas, The          BHS  7.675112e+09
# 15   2010    YR2010                 Bahrain          BHR  2.334013e+10
# 16   2010    YR2010              Bangladesh          BGD  1.246171e+11
# 17   2010    YR2010                Barbados          BRB  4.362050e+09
# 18   2010    YR2010                 Belarus          BLR  5.612622e+10
# 19   2010    YR2010                 Belgium          BEL  4.987890e+11
# 20   2010    YR2010                  Belize          BLZ  1.239593e+09
# 21   2010    YR2010                   Benin          BEN  6.916758e+09
# 22   2010    YR2010                 Bermuda          BMU  7.163899e+09
# 23   2010    YR2010                  Bhutan          BTN  1.497492e+09
# 24   2010    YR2010                 Bolivia          BOL  1.878552e+10
# 25   2010    YR2010  Bosnia and Herzegovina          BIH  1.745615e+10
# 26   2010    YR2010                Botswana          BWA  1.223710e+10
# 27   2010    YR2010                  Brazil          BRA  2.144024e+12
# 29   2010    YR2010       Brunei Darussalam          BRN  1.360689e+10
# 30   2010    YR2010                Bulgaria          BGR  4.955618e+10
# 31   2010    YR2010            Burkina Faso          BFA  8.744700e+09
# 32   2010    YR2010                 Burundi          BDI  2.014764e+09
# 33   2010    YR2010              Cabo Verde          CPV  1.591147e+09
# ..    ...       ...                     ...          ...           ...
# 231  2010    YR2010                Suriname          SUR  4.264098e+09
# 232  2010    YR2010                  Sweden          SWE  5.026816e+11
# 233  2010    YR2010             Switzerland          CHE  6.163804e+11
# 235  2010    YR2010              Tajikistan          TJK  6.969687e+09
# 236  2010    YR2010                Tanzania          TZA  3.107783e+10
# 237  2010    YR2010                Thailand          THA  3.268156e+11
# 238  2010    YR2010             Timor-Leste          TLS  3.337447e+09
# 239  2010    YR2010                    Togo          TGO  2.761612e+09
# 240  2010    YR2010                   Tonga          TON  3.814213e+08
# 241  2010    YR2010     Trinidad and Tobago          TTO  2.107845e+10
# 242  2010    YR2010                 Tunisia          TUN  4.198351e+10
# 243  2010    YR2010                  Turkey          TUR  7.653866e+11
# 244  2010    YR2010            Turkmenistan          TKM  2.068916e+10
# 246  2010    YR2010                  Tuvalu          TUV  5.091873e+07
# 247  2010    YR2010                  Uganda          UGA  1.984912e+10
# 248  2010    YR2010                 Ukraine          UKR  1.340042e+11
# 249  2010    YR2010    United Arab Emirates          ARE  2.897808e+11
# 250  2010    YR2010          United Kingdom          GBR  2.460887e+12
# 251  2010    YR2010           United States          USA  1.512113e+13
# 252  2010    YR2010     Upper middle income          UMC  1.511562e+13
# 253  2010    YR2010                 Uruguay          URY  3.878197e+10
# 254  2010    YR2010              Uzbekistan          UZB  4.052778e+10
# 255  2010    YR2010                 Vanuatu          VUT  6.757211e+08
# 256  2010    YR2010           Venezuela, RB          VEN  3.883414e+11
# 257  2010    YR2010                 Vietnam          VNM  1.115128e+11
# 259  2010    YR2010      West Bank and Gaza          PSE  9.512200e+09
# 260  2010    YR2010                   World          WLD  6.591609e+13
# 261  2010    YR2010             Yemen, Rep.          YEM  2.908777e+10
# 262  2010    YR2010                  Zambia          ZMB  1.890254e+10
# 263  2010    YR2010                Zimbabwe          ZWE  8.714543e+09
#
#          Surface
# 0       652860.0
# 1        28750.0
# 2      2381740.0
# 5      1246700.0
# 6          440.0
# 7     13779283.0
# 8      2780400.0
# 9        29740.0
# 11     7741220.0
# 12       83879.0
# 13       86600.0
# 14       13880.0
# 15         762.0
# 16      148460.0
# 17         430.0
# 18      207600.0
# 19       30530.0
# 20       22970.0
# 21      114760.0
# 22          50.0
# 23       38394.0
# 24     1098580.0
# 25       51210.0
# 26      581730.0
# 27     8515770.0
# 29        5770.0
# 30      111000.0
# 31      274220.0
# 32       27830.0
# 33        4030.0
# ..           ...
# 231     163820.0
# 232     450300.0
# 233      41290.0
# 235     142550.0
# 236     947300.0
# 237     513120.0
# 238      14870.0
# 239      56790.0
# 240        750.0
# 241       5130.0
# 242     163610.0
# 243     785350.0
# 244     488100.0
# 246         30.0
# 247     241550.0
# 248     603550.0
# 249      83600.0
# 250     243610.0
# 251    9831510.0
# 252   56967185.0
# 253     176220.0
# 254     447400.0
# 255      12190.0
# 256     912050.0
# 257     330954.0
# 259       6020.0
# 260  134311372.1
# 261     527970.0
# 262     752610.0
# 263     390760.0
#
# [239 rows x 6 columns]

# %% [markdown]
# # Read dataset

# %% [markdown]
# ### Import dataset

# %%
dfautres = pd.read_csv("autres_Data.txt",sep="\t",header=0)
dfautres.head()
# Out:
#    Time Time Code    Country Name Country Code  Gvnt_health_exp  Food Deficit  \
# 0  2010    YR2010     Afghanistan          AFG         0.469157         158.0
# 1  2010    YR2010         Albania          ALB         2.512062           NaN
# 2  2010    YR2010         Algeria          DZA         3.555519          40.0
# 3  2010    YR2010  American Samoa          ASM              NaN           NaN
# 4  2010    YR2010         Andorra          AND         6.328402           NaN
#
#    Life Expectancy  Nat_resources_rents
# 0           61.226             0.732845
# 1           76.652             2.070109
# 2           74.676            19.977893
# 3              NaN             0.000000
# 4              NaN             0.000000

# %% [markdown]
# ### Drop rows with missing values

# %%
dfautres = dfautres.dropna()
dfautres.head()
# Out:
#    Time Time Code Country Name Country Code  Gvnt_health_exp  Food Deficit  \
# 0  2010    YR2010  Afghanistan          AFG         0.469157    158.000000
# 2  2010    YR2010      Algeria          DZA         3.555519     40.000000
# 5  2010    YR2010       Angola          AGO         1.704052    149.000000
# 7  2010    YR2010   Arab World          ARB         2.355628     73.402535
# 8  2010    YR2010    Argentina          ARG         3.710831     10.000000
#
#    Life Expectancy  Nat_resources_rents
# 0        61.226000             0.732845
# 2        74.676000            19.977893
# 5        58.192000            39.037754
# 7        70.041054            27.643199
# 8        75.595000             3.137998

# %% [markdown]
# # Merge datasets

# %%
data = pd.merge(dfgni, dfautres, how='inner', on=['Country Name', 'Country Code'])

# %%
data=data.drop(columns=['Time_x', 'Time Code_x', 'Time_y', 'Time Code_y' ])

# %%
# set index with country code
data = data.set_index('Country Code')

# %%
data.head()
# Out:
#              Country Name           GNI     Surface  Gvnt_health_exp  \
# Country Code
# AFG           Afghanistan  1.599880e+10    652860.0         0.469157
# DZA               Algeria  1.608199e+11   2381740.0         3.555519
# AGO                Angola  7.443928e+10   1246700.0         1.704052
# ARB            Arab World  2.091921e+12  13779283.0         2.355628
# ARG             Argentina  4.091479e+11   2780400.0         3.710831
#
#               Food Deficit  Life Expectancy  Nat_resources_rents
# Country Code
# AFG             158.000000        61.226000             0.732845
# DZA              40.000000        74.676000            19.977893
# AGO             149.000000        58.192000            39.037754
# ARB              73.402535        70.041054            27.643199
# ARG              10.000000        75.595000             3.137998

# %%
len(data)
# Out:
# 146
